# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()## öncelikle datayı kontrol ediyoruz
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()## null olmayan değer var mı diye kontrol ediyoruz
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_25092\686912093.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataFrame["price"])
# C:\Users\yusuf\anaconda3\envs\pppp11\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %%
sbn.scatterplot(x="mileage",y="price", data=dataFrame)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False).head(20)## en yüksek fiyatlı arabaları getirmek
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price",ascending=True).head(20)## en düşük fiyatlı arabaları getirmek
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame)
# Out:
# 13119

# %%
len(dataFrame)*0.01
# Out:
# 131.19

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price", ascending=False).iloc[131:]

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.displot(yuzdeDoksanDokuzDf["price"])
# Out:
# C:\Users\yusuf\anaconda3\envs\pppp11\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dataFrame.groupby("year").mean(["price"])## yıllardaki fiyat ortalamasını alıyor
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
yuzdeDoksanDokuzDf.groupby("year").mean(["price"])
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
dataFrame = dataFrame[dataFrame.year != 1970]

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame = dataFrame.drop("transmission", axis=1)

# %%
y=dataFrame["price"].values
x=dataFrame.drop("price",axis=1).values

# %%
y
# Out:
# array([ 5200, 34948, 49948, ..., 30999, 37990, 54999], dtype=int64)

# %%
x
# Out:
# array([[2.0050e+03, 6.3000e+04, 3.2500e+02, 3.2100e+01, 1.8000e+00],
#        [2.0170e+03, 2.7000e+04, 2.0000e+01, 6.1400e+01, 2.1000e+00],
#        [2.0160e+03, 6.2000e+03, 5.5500e+02, 2.8000e+01, 5.5000e+00],
#        ...,
#        [2.0190e+03, 1.1612e+04, 1.4500e+02, 4.1500e+01, 2.1000e+00],
#        [2.0190e+03, 2.4260e+03, 1.4500e+02, 4.5600e+01, 2.0000e+00],
#        [2.0190e+03, 2.0750e+03, 1.4500e+02, 5.2300e+01, 2.9000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9182

# %%
len(x_test)
# Out:
# 3936

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9182, 5)

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train, y=y_train,validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 1s 7ms/step - loss: 741601216.0000 - val_loss: 770452160.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741565824.0000 - val_loss: 770389376.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741433216.0000 - val_loss: 770134272.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 2ms/step - loss: 740904256.0000 - val_loss: 769151424.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 2ms/step - loss: 739091712.0000 - val_loss: 766097920.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 2ms/step - loss: 734100672.0000 - val_loss: 758355008.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 2ms/step - loss: 722427456.0000 - val_loss: 741291968.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 2ms/step - loss: 698517376.0000 - val_loss: 708538752.0000
# Epoch 9/300
# ...

# %%
kayipVerisi=pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  741601216.0  770452160.0
# 1  741565824.0  770389376.0
# 2  741433216.0  770134272.0
# 3  740904256.0  769151424.0
# 4  739091712.0  766097920.0

# %%
kayipVerisi.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
# Out:
# 123/123 [==============================] - 0s 691us/step

# %%
tahminDizisi
# Out:
# array([[39163.11 ],
#        [30298.71 ],
#        [41526.715],
#        ...,
#        [23056.879],
#        [18713.902],
#        [21251.002]], dtype=float32)

# %%
mean_absolute_error(y_test,tahminDizisi)##3432 pound bir fark var
# Out:
# 3432.0101717972175

# %%
dataFrame.describe()## ortalama fiyat 24000 pound yani 3400 sapabilir çok sorun değil
# Out:
#                year          price       mileage           tax           mpg  \
# count  13118.000000   13118.000000   13118.00000  13118.000000  13118.000000
# mean    2017.299893   24698.574020   21950.16504    129.958835     55.157059
# std        2.186129   11843.126668   21177.20571     65.244877     15.220025
# min     1997.000000     650.000000       1.00000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6096.75000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.00000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31781.75000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.00000    580.000000    217.300000
#
#          engineSize
# count  13118.000000
# mean       2.071688
# std        0.572162
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test,y_test,"g-*")

# %%
dataFrame.iloc[2]
# Out:
# year           2016.0
# price         49948.0
# mileage        6200.0
# tax             555.0
# mpg              28.0
# engineSize        5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = dataFrame.drop("price",axis=1).iloc[2]

# %%
yeniArabaSeries
# Out:
# year          2016.0
# mileage       6200.0
# tax            555.0
# mpg             28.0
# engineSize       5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))

# %%
model.predict(yeniArabaSeries)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([[59672.715]], dtype=float32)
